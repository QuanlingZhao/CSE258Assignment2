# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

from torch.utils.data import DataLoader
from torch.nn.functional import relu

from collections import defaultdict, OrderedDict
from sklearn import metrics

# %%
print('Torch', torch.__version__, 'CUDA', torch.version.cuda)
print('Device:', torch.device('cuda:0'))

# !nvcc --version

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.is_available(), device
# Out:
# Torch 1.12.1+cu113 CUDA 11.3
# Device: cuda:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0
# (True, device(type='cuda'))

# %%
config = {}

NUM_TARGETS= 3

USER_PATHWAY  = [256, 128, 64]
ITEM_PATHWAY = [256, 128, 64]
COMBINED_PATHWAY = [256, 128, 64, 16]

EMBED_DIM = 10
NUM_ITEM_EMBED = 1378
NUM_USER_EMBED = 47958
NUM_CUPSIZE_EMBED =  12
NUM_CATEGORY_EMBED = 7

NUM_USER_NUMERIC = 5
NUM_ITEM_NUMERIC = 2

DROPOUT = 0.3

EPOCHS = 5
LR = 0.001
WEIGHT_DECAY = 0.0001
BATCH_SIZE = 128

# %%
class ModCloth(torch.utils.data.Dataset):
    def __init__(self,datapath):
        self.data = pd.read_csv(datapath)

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, idx):

        r = self.data.iloc[idx,:]

        return {
            "user_id" : np.array(r['user_id'], dtype=np.int64),
            "cup_size" : np.array(r['cup_size'], dtype=np.int64),
            "user_numeric" : np.array([r['waist'], r['hips'], r['bra_size'], r['height'], r['shoe_size']], dtype=np.float32),
            "item_id" : np.array(r['item_id'], dtype = np.int64),
            "category" :np.array(r['category'], dtype = np.int64),
            "item_numeric" : np.array([r['size'], r['quality']], dtype=np.float32),
            "fit" : np.array(r['fit'], dtype=np.int64)
        }

datasets = OrderedDict()
splits = ['train', 'valid']
datasets['train'] =  ModCloth("data/modcloth_final_data_processed_train.csv")
datasets['valid'] =  ModCloth("data/modcloth_final_data_processed_valid.csv")
datasets['test'] = ModCloth("data/modcloth_final_data_processed_test.csv")

# %%
# macro - Calculate metrics for each label, and find their unweighted mean. This does not take label imbalance into account
# weighted - Calculate metrics for each label, and find their average weighted by support (the number of true instances for each label). This alters ‘macro’ to account for label imbalance; it can result in an F-score that is not between precision and recall.

def compute_metrics(target, pred_probs, averaging = "macro"):

    pred_labels = pred_probs.argmax(-1)
    precision = metrics.precision_score(target, pred_labels, average=averaging)
    recall = metrics.recall_score(target, pred_labels, average=averaging)
    f1_score = metrics.f1_score(target, pred_labels, average=averaging)
    accuracy = metrics.accuracy_score(target, pred_labels)
    auc = metrics.roc_auc_score(target, pred_probs, average=averaging, multi_class="ovr")

    return precision, recall, f1_score, accuracy, auc

# %%
class Base(nn.Module):
    def __init__(self, user_pathway, item_pathway, combined_pathway, embed_dim, num_item_embed, num_user_embed, num_cupsize_embed, num_category_embed, dropout):
        super().__init__()
       
        self.user_pathway = user_pathway
        self.item_pathway = item_pathway
        self.combined_pathway = combined_pathway
        self.embedding_dim = embed_dim

        self.user_embedding = nn.Embedding(num_user_embed, embed_dim, max_norm=1.0 )
        self.cup_size_embedding = nn.Embedding(num_cupsize_embed, embed_dim, max_norm=1.0 )
        self.item_embedding = nn.Embedding(num_item_embed, embed_dim, max_norm=1.0 )
        self.category_embedding = nn.Embedding(num_category_embed, embed_dim, max_norm=1.0 )


    def forward(self, batch_input):
        # Customer Pathway
        user_emb = self.user_embedding(batch_input["user_id"])
        cup_size_emb = self.cup_size_embedding(batch_input["cup_size"])
        user_representation = torch.cat( [user_emb, cup_size_emb, batch_input["user_numeric"]], dim=-1 )
        user_representation = self.user_transform_blocks(user_representation)

        # Article Pathway
        item_emb = self.item_embedding(batch_input["item_id"])
        category_emb = self.category_embedding(batch_input["category"])
        item_representation = torch.cat( [item_emb, category_emb, batch_input["item_numeric"]], dim=-1 )
        item_representation = self.item_transform_blocks(item_representation)

        # Combine the pathways
        combined_representation = torch.cat( [user_representation, item_representation], dim=-1 )
        combined_representation = self.combined_blocks(combined_representation)

        # Output layer of logits
        logits = self.hidden2output(combined_representation)
        pred_probs = F.softmax(logits, dim=-1)

        return logits, pred_probs

# %%
class SFNet(Base):
    def __init__(self, user_pathway, item_pathway, combined_pathway, embed_dim, num_item_embed, num_user_embed, num_cupsize_embed, num_category_embed, dropout):
        super().__init__(user_pathway, item_pathway, combined_pathway, embed_dim, num_item_embed, num_user_embed, num_cupsize_embed, num_category_embed, dropout)

        # Customer pathway transformation  ==  user_embedding_dim + cup_size_embedding_dim + num_user_numeric_features
        user_features_input_size = 2 * self.embedding_dim + NUM_USER_NUMERIC
        self.user_pathway.insert(0, user_features_input_size)
        self.user_transform_blocks = []
        for i in range(1, len(self.user_pathway)):
            self.user_transform_blocks.append( SkipBlock( self.user_pathway[i - 1], self.user_pathway[i] ) )
            self.user_transform_blocks.append(nn.Dropout(DROPOUT))
        self.user_transform_blocks = nn.Sequential(*self.user_transform_blocks)

        # Article pathway transformation == item_embedding_dim + category_embedding_dim + num_item_numeric_features
        item_features_input_size = 2 * self.embedding_dim + NUM_ITEM_NUMERIC
        self.item_pathway.insert(0, item_features_input_size)
        self.item_transform_blocks = []
        for i in range(1, len(self.item_pathway)):
            self.item_transform_blocks.append( SkipBlock( self.item_pathway[i - 1], self.item_pathway[i]) )
            self.item_transform_blocks.append(nn.Dropout(DROPOUT))
        self.item_transform_blocks = nn.Sequential(*self.item_transform_blocks)

        # Combined top layer pathway
        # u = output dim of user_transform_blocks, # t = output dim of item_transform_blocks
        # Pathway combination through [u, t] # Hence, input dimension will be 2*dim(u)
        combined_layer_input_size = 2 * self.user_pathway[-1]
        self.combined_pathway.insert(0, combined_layer_input_size)
        self.combined_blocks = []
        for i in range(1, len(self.combined_pathway)):
            self.combined_blocks.append( SkipBlock( self.combined_pathway[i - 1], self.combined_pathway[i]) )
            self.combined_blocks.append(nn.Dropout(DROPOUT))
        self.combined_blocks = nn.Sequential(*self.combined_blocks)

        # Linear transformation from last hidden layer to output
        self.hidden2output = nn.Linear(self.combined_pathway[-1], NUM_TARGETS)


class SkipBlock(nn.Module):
    def __init__(self, input_dim, output_dim):
        """ Skip Connection for feed-forward  - ResNet Block """
        super().__init__()
        self.W1 = nn.Linear(input_dim, output_dim)
        self.W2 = nn.Linear(output_dim, output_dim)
        self.I = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        """  z = ReLU(   W2( ReLU( W1(x))) + Projection(x))    """
        z = relu(self.W2(relu(self.W1(x))) + self.I(x))
        return z

# %%
class MLP(Base):
    def __init__(self,user_pathway, item_pathway, combined_pathway, embed_dim, num_item_embed, num_user_embed, num_cupsize_embed, num_category_embed, dropout):
        super().__init__(user_pathway, item_pathway, combined_pathway, embed_dim, num_item_embed, num_user_embed, num_cupsize_embed, num_category_embed, dropout)

        # Customer pathway transformation  ==  user_embedding_dim + cup_size_embedding_dim + num_user_numeric_features
        user_features_input_size = 2 * self.embedding_dim + NUM_USER_NUMERIC
        self.user_pathway.insert(0, user_features_input_size)
        self.user_transform_blocks = []
        for i in range(1, len(self.user_pathway)):
            self.user_transform_blocks.append( LinearBlock( self.user_pathway[i - 1], self.user_pathway[i] ) )
        self.user_transform_blocks = nn.Sequential(*self.user_transform_blocks)

        # Article pathway transformation == item_embedding_dim + category_embedding_dim + num_item_numeric_features
        item_features_input_size = 2 * self.embedding_dim + NUM_ITEM_NUMERIC
        self.item_pathway.insert(0, item_features_input_size)
        self.item_transform_blocks = []
        for i in range(1, len(self.item_pathway)):
            self.item_transform_blocks.append( LinearBlock( self.item_pathway[i - 1], self.item_pathway[i])  )
        self.item_transform_blocks = nn.Sequential(*self.item_transform_blocks)

        # Combined top layer pathway
        # u = output dim of user_transform_blocks, # t = output dim of item_transform_blocks
        # Pathway combination through [u, t] # Hence, input dimension will be 4*dim(u)
        combined_layer_input_size = 2 * self.user_pathway[-1]
        self.combined_pathway.insert(0, combined_layer_input_size)
        self.combined_blocks = []
        for i in range(1, len(self.combined_pathway)):
            self.combined_blocks.append( LinearBlock( self.combined_pathway[i - 1], self.combined_pathway[i]) )
        self.combined_blocks = nn.Sequential(*self.combined_blocks)

        # Linear transformation from last hidden layer to output
        self.hidden2output = nn.Linear(self.combined_pathway[-1], NUM_TARGETS)


class LinearBlock(nn.Module):
    def __init__(self, input_dim, output_dim):
        """ Skip Connection for feed-forward  - ResNet Block """
        super().__init__()
        self.W1 = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        """  z = ReLU(   W2( ReLU( W1(x))) + Projection(x))    """
        return relu(self.W1(x))

# %%
model = MLP(USER_PATHWAY, ITEM_PATHWAY, COMBINED_PATHWAY, EMBED_DIM, NUM_ITEM_EMBED, NUM_USER_EMBED, NUM_CUPSIZE_EMBED, NUM_CATEGORY_EMBED, DROPOUT)
model = model.to(device)

# print("-" * 50)
# print(model)

print("-" * 50)
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of model parameters: {total_params}")
print("-" * 50)

loss_criterion = torch.nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr = LR, weight_decay= WEIGHT_DECAY)
# Out:
# --------------------------------------------------
# Number of model parameters: 663665
# --------------------------------------------------

# %%
step = 0

tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.Tensor

for epoch in range(EPOCHS):

    for d in datasets:
        for split in splits:
            data_loader = DataLoader( dataset=datasets[split], batch_size=BATCH_SIZE, shuffle = (split == "train") )

            loss_tracker = defaultdict(tensor)

            # Enable/Disable Dropout
            if split == "train":
                model.train()
            else:
                model.eval()
                target_tracker = []
                pred_tracker = []

            for iteration, batch in enumerate(data_loader):

                for k, v in batch.items():
                    batch[k] = v.to(device)

                # Forward pass
                logits, pred_probs = model(batch)

                # loss calculation
                loss = loss_criterion(logits, batch["fit"])   # batch['fit'] are the true labels

                # backward + optimization
                if split == "train":
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                    step += 1

                # bookkeepeing
                loss_tracker["Total Loss"] = torch.cat((loss_tracker["Total Loss"], loss.view(1)))

                if iteration % 100 == 0 or iteration + 1 == len(data_loader):
                    print(f"{split.upper()} Batch Stats {iteration}/{len(data_loader)}, Loss={loss.item() :.2f}")

                if split == "valid":
                    target_tracker.append(batch["fit"].cpu().numpy())
                    pred_tracker.append(pred_probs.cpu().data.numpy())

            print( f"{split.upper()} Epoch {epoch + 1} / {EPOCHS}, Mean Total Loss {torch.mean(loss_tracker['Total Loss'])}")
# Out:
# TRAIN Batch Stats 0/260, Loss=1.09
# TRAIN Batch Stats 100/260, Loss=0.81
# TRAIN Batch Stats 200/260, Loss=0.88
# TRAIN Batch Stats 259/260, Loss=0.73
# TRAIN Epoch 1 / 5, Mean Total Loss 0.8250993490219116
# VALID Batch Stats 0/65, Loss=0.71
# VALID Batch Stats 64/65, Loss=0.81
# VALID Epoch 1 / 5, Mean Total Loss 0.806228518486023
# TRAIN Batch Stats 0/260, Loss=0.78
# TRAIN Batch Stats 100/260, Loss=0.84
# TRAIN Batch Stats 200/260, Loss=0.77
# TRAIN Batch Stats 259/260, Loss=0.82
# TRAIN Epoch 1 / 5, Mean Total Loss 0.7979980707168579
# VALID Batch Stats 0/65, Loss=0.71
# VALID Batch Stats 64/65, Loss=0.79
# VALID Epoch 1 / 5, Mean Total Loss 0.7956191897392273
# TRAIN Batch Stats 0/260, Loss=0.82
# TRAIN Batch Stats 100/260, Loss=0.82
# TRAIN Batch Stats 200/260, Loss=0.81
# TRAIN Batch Stats 259/260, Loss=0.92
# TRAIN Epoch 1 / 5, Mean Total Loss 0.791816771030426
# VALID Batch Stats 0/65, Loss=0.68
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 1 / 5, Mean Total Loss 0.7933549880981445
# TRAIN Batch Stats 0/260, Loss=0.74
# TRAIN Batch Stats 100/260, Loss=0.82
# TRAIN Batch Stats 200/260, Loss=0.70
# TRAIN Batch Stats 259/260, Loss=0.75
# TRAIN Epoch 2 / 5, Mean Total Loss 0.7861600518226624
# VALID Batch Stats 0/65, Loss=0.68
# VALID Batch Stats 64/65, Loss=0.76
# VALID Epoch 2 / 5, Mean Total Loss 0.7908594012260437
# TRAIN Batch Stats 0/260, Loss=0.72
# TRAIN Batch Stats 100/260, Loss=0.73
# TRAIN Batch Stats 200/260, Loss=0.63
# TRAIN Batch Stats 259/260, Loss=0.77
# TRAIN Epoch 2 / 5, Mean Total Loss 0.7812672257423401
# VALID Batch Stats 0/65, Loss=0.69
# VALID Batch Stats 64/65, Loss=0.77
# VALID Epoch 2 / 5, Mean Total Loss 0.7881695032119751
# TRAIN Batch Stats 0/260, Loss=0.86
# TRAIN Batch Stats 100/260, Loss=0.87
# TRAIN Batch Stats 200/260, Loss=0.80
# TRAIN Batch Stats 259/260, Loss=0.70
# TRAIN Epoch 2 / 5, Mean Total Loss 0.7725120186805725
# VALID Batch Stats 0/65, Loss=0.66
# VALID Batch Stats 64/65, Loss=0.76
# VALID Epoch 2 / 5, Mean Total Loss 0.7893105745315552
# TRAIN Batch Stats 0/260, Loss=0.77
# TRAIN Batch Stats 100/260, Loss=0.69
# TRAIN Batch Stats 200/260, Loss=0.64
# TRAIN Batch Stats 259/260, Loss=0.77
# TRAIN Epoch 3 / 5, Mean Total Loss 0.6922531723976135
# VALID Batch Stats 0/65, Loss=0.70
# VALID Batch Stats 64/65, Loss=0.72
# VALID Epoch 3 / 5, Mean Total Loss 0.829005777835846
# TRAIN Batch Stats 0/260, Loss=0.57
# TRAIN Batch Stats 100/260, Loss=0.58
# TRAIN Batch Stats 200/260, Loss=0.43
# TRAIN Batch Stats 259/260, Loss=0.48
# TRAIN Epoch 3 / 5, Mean Total Loss 0.5181536078453064
# VALID Batch Stats 0/65, Loss=0.74
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 3 / 5, Mean Total Loss 0.9203105568885803
# TRAIN Batch Stats 0/260, Loss=0.38
# TRAIN Batch Stats 100/260, Loss=0.35
# TRAIN Batch Stats 200/260, Loss=0.38
# TRAIN Batch Stats 259/260, Loss=0.41
# TRAIN Epoch 3 / 5, Mean Total Loss 0.4049628674983978
# VALID Batch Stats 0/65, Loss=0.78
# VALID Batch Stats 64/65, Loss=0.89
# VALID Epoch 3 / 5, Mean Total Loss 1.0249558687210083
# TRAIN Batch Stats 0/260, Loss=0.31
# TRAIN Batch Stats 100/260, Loss=0.30
# TRAIN Batch Stats 200/260, Loss=0.25
# TRAIN Batch Stats 259/260, Loss=0.49
# TRAIN Epoch 4 / 5, Mean Total Loss 0.3226317763328552
# VALID Batch Stats 0/65, Loss=0.84
# VALID Batch Stats 64/65, Loss=1.03
# VALID Epoch 4 / 5, Mean Total Loss 1.1440484523773193
# TRAIN Batch Stats 0/260, Loss=0.19
# TRAIN Batch Stats 100/260, Loss=0.31
# TRAIN Batch Stats 200/260, Loss=0.21
# TRAIN Batch Stats 259/260, Loss=0.20
# TRAIN Epoch 4 / 5, Mean Total Loss 0.27063441276550293
# VALID Batch Stats 0/65, Loss=0.91
# VALID Batch Stats 64/65, Loss=1.16
# VALID Epoch 4 / 5, Mean Total Loss 1.2460811138153076
# TRAIN Batch Stats 0/260, Loss=0.15
# TRAIN Batch Stats 100/260, Loss=0.25
# TRAIN Batch Stats 200/260, Loss=0.24
# TRAIN Batch Stats 259/260, Loss=0.14
# TRAIN Epoch 4 / 5, Mean Total Loss 0.22891183197498322
# VALID Batch Stats 0/65, Loss=0.89
# VALID Batch Stats 64/65, Loss=1.08
# VALID Epoch 4 / 5, Mean Total Loss 1.209553837776184
# TRAIN Batch Stats 0/260, Loss=0.17
# TRAIN Batch Stats 100/260, Loss=0.16
# TRAIN Batch Stats 200/260, Loss=0.30
# TRAIN Batch Stats 259/260, Loss=0.18
# TRAIN Epoch 5 / 5, Mean Total Loss 0.18800289928913116
# VALID Batch Stats 0/65, Loss=0.87
# VALID Batch Stats 64/65, Loss=1.17
# VALID Epoch 5 / 5, Mean Total Loss 1.2442095279693604
# TRAIN Batch Stats 0/260, Loss=0.18
# TRAIN Batch Stats 100/260, Loss=0.18
# TRAIN Batch Stats 200/260, Loss=0.19
# TRAIN Batch Stats 259/260, Loss=0.11
# TRAIN Epoch 5 / 5, Mean Total Loss 0.16579683125019073
# VALID Batch Stats 0/65, Loss=1.05
# VALID Batch Stats 64/65, Loss=1.42
# VALID Epoch 5 / 5, Mean Total Loss 1.5005615949630737
# TRAIN Batch Stats 0/260, Loss=0.09
# TRAIN Batch Stats 100/260, Loss=0.19
# TRAIN Batch Stats 200/260, Loss=0.16
# TRAIN Batch Stats 259/260, Loss=0.14
# TRAIN Epoch 5 / 5, Mean Total Loss 0.15371856093406677
# VALID Batch Stats 0/65, Loss=0.97
# VALID Batch Stats 64/65, Loss=1.31
# VALID Epoch 5 / 5, Mean Total Loss 1.4485458135604858

# %%
target_tracker = []
pred_tracker = []

print("Preparing test data ...")

data_loader = DataLoader(dataset = datasets['test'], batch_size = BATCH_SIZE, shuffle=False)

print("Evaluating model on test data ...")
model.eval()
with torch.no_grad():

    for iteration, batch in enumerate(data_loader):

        for k, v in batch.items():
            batch[k] = v.to(device)

        # Forward pass
        _, pred_probs = model(batch)

        target_tracker.append(batch["fit"].cpu().numpy())
        pred_tracker.append(pred_probs.cpu().data.numpy())

target_tracker = np.stack(target_tracker[:-1]).reshape(-1)
pred_tracker = np.stack(pred_tracker[:-1], axis=0).reshape(-1, NUM_TARGETS)
precision, recall, f1_score, accuracy, auc = compute_metrics(target_tracker, pred_tracker, averaging = "weighted")

print("-" * 50)
print(f"Metrics:\n Precision = {precision}\n Recall = {recall}\n F1-score = {f1_score}\n Accuracy = {accuracy}\n AUC = {auc}\n ")
print("-" * 50)
# Out:
# Preparing test data ...
# Evaluating model on test data ...
# --------------------------------------------------
# Metrics:
#  Precision = 0.605288488409015
#  Recall = 0.59619140625
#  F1-score = 0.5918466993316605
#  Accuracy = 0.59619140625
#  AUC = 0.6304495162271756
#
# --------------------------------------------------

# %%
model = SFNet(USER_PATHWAY, ITEM_PATHWAY, COMBINED_PATHWAY, EMBED_DIM, NUM_ITEM_EMBED, NUM_USER_EMBED, NUM_CUPSIZE_EMBED, NUM_CATEGORY_EMBED, DROPOUT)
model = model.to(device)

# print("-" * 50)
# print(model)

print("-" * 50)
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of model parameters: {total_params}")
print("-" * 50)

loss_criterion = torch.nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr = LR, weight_decay= WEIGHT_DECAY)
# Out:
# --------------------------------------------------
# Number of model parameters: 1146397
# --------------------------------------------------

# %%
step = 0

tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.Tensor

for epoch in range(EPOCHS):

    for d in datasets:
        for split in splits:
            data_loader = DataLoader( dataset=datasets[split], batch_size=BATCH_SIZE, shuffle = (split == "train") )

            loss_tracker = defaultdict(tensor)

            # Enable/Disable Dropout
            if split == "train":
                model.train()
            else:
                model.eval()
                target_tracker = []
                pred_tracker = []

            for iteration, batch in enumerate(data_loader):

                for k, v in batch.items():
                    batch[k] = v.to(device)

                # Forward pass
                logits, pred_probs = model(batch)

                # loss calculation
                loss = loss_criterion(logits, batch["fit"])   # batch['fit'] are the true labels

                # backward + optimization
                if split == "train":
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                    step += 1

                # bookkeepeing
                loss_tracker["Total Loss"] = torch.cat((loss_tracker["Total Loss"], loss.view(1)))

                if iteration % 100 == 0 or iteration + 1 == len(data_loader):
                    print(f"{split.upper()} Batch Stats {iteration}/{len(data_loader)}, Loss={loss.item() :.2f}")

                if split == "valid":
                    target_tracker.append(batch["fit"].cpu().numpy())
                    pred_tracker.append(pred_probs.cpu().data.numpy())

            print( f"{split.upper()} Epoch {epoch + 1} / {EPOCHS}, Mean Total Loss {torch.mean(loss_tracker['Total Loss'])}")
# Out:
# TRAIN Batch Stats 0/260, Loss=1.08
# TRAIN Batch Stats 100/260, Loss=0.88
# TRAIN Batch Stats 200/260, Loss=0.84
# TRAIN Batch Stats 259/260, Loss=0.86
# TRAIN Epoch 1 / 5, Mean Total Loss 0.8530062437057495
# VALID Batch Stats 0/65, Loss=0.71
# VALID Batch Stats 64/65, Loss=0.82
# VALID Epoch 1 / 5, Mean Total Loss 0.8088796734809875
# TRAIN Batch Stats 0/260, Loss=0.98
# TRAIN Batch Stats 100/260, Loss=0.76
# TRAIN Batch Stats 200/260, Loss=0.81
# TRAIN Batch Stats 259/260, Loss=0.82
# TRAIN Epoch 1 / 5, Mean Total Loss 0.8254348635673523
# VALID Batch Stats 0/65, Loss=0.71
# VALID Batch Stats 64/65, Loss=0.81
# VALID Epoch 1 / 5, Mean Total Loss 0.8033958077430725
# TRAIN Batch Stats 0/260, Loss=0.95
# TRAIN Batch Stats 100/260, Loss=0.76
# TRAIN Batch Stats 200/260, Loss=0.78
# TRAIN Batch Stats 259/260, Loss=0.85
# TRAIN Epoch 1 / 5, Mean Total Loss 0.8144084215164185
# VALID Batch Stats 0/65, Loss=0.70
# VALID Batch Stats 64/65, Loss=0.80
# VALID Epoch 1 / 5, Mean Total Loss 0.80019211769104
# TRAIN Batch Stats 0/260, Loss=0.87
# TRAIN Batch Stats 100/260, Loss=0.82
# TRAIN Batch Stats 200/260, Loss=0.86
# TRAIN Batch Stats 259/260, Loss=0.75
# TRAIN Epoch 2 / 5, Mean Total Loss 0.8061738014221191
# VALID Batch Stats 0/65, Loss=0.70
# VALID Batch Stats 64/65, Loss=0.80
# VALID Epoch 2 / 5, Mean Total Loss 0.7962042093276978
# TRAIN Batch Stats 0/260, Loss=0.87
# TRAIN Batch Stats 100/260, Loss=0.78
# TRAIN Batch Stats 200/260, Loss=0.69
# TRAIN Batch Stats 259/260, Loss=0.73
# TRAIN Epoch 2 / 5, Mean Total Loss 0.8003198504447937
# VALID Batch Stats 0/65, Loss=0.68
# VALID Batch Stats 64/65, Loss=0.79
# VALID Epoch 2 / 5, Mean Total Loss 0.7965295910835266
# TRAIN Batch Stats 0/260, Loss=0.79
# TRAIN Batch Stats 100/260, Loss=0.70
# TRAIN Batch Stats 200/260, Loss=0.83
# TRAIN Batch Stats 259/260, Loss=0.84
# TRAIN Epoch 2 / 5, Mean Total Loss 0.7983236312866211
# VALID Batch Stats 0/65, Loss=0.68
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 2 / 5, Mean Total Loss 0.7930476069450378
# TRAIN Batch Stats 0/260, Loss=0.81
# TRAIN Batch Stats 100/260, Loss=0.84
# TRAIN Batch Stats 200/260, Loss=0.85
# TRAIN Batch Stats 259/260, Loss=0.67
# TRAIN Epoch 3 / 5, Mean Total Loss 0.794068455696106
# VALID Batch Stats 0/65, Loss=0.70
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 3 / 5, Mean Total Loss 0.7937692403793335
# TRAIN Batch Stats 0/260, Loss=0.85
# TRAIN Batch Stats 100/260, Loss=0.75
# TRAIN Batch Stats 200/260, Loss=0.80
# TRAIN Batch Stats 259/260, Loss=0.83
# TRAIN Epoch 3 / 5, Mean Total Loss 0.791766345500946
# VALID Batch Stats 0/65, Loss=0.69
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 3 / 5, Mean Total Loss 0.7910228967666626
# TRAIN Batch Stats 0/260, Loss=0.82
# TRAIN Batch Stats 100/260, Loss=0.72
# TRAIN Batch Stats 200/260, Loss=0.87
# TRAIN Batch Stats 259/260, Loss=0.65
# TRAIN Epoch 3 / 5, Mean Total Loss 0.7894464135169983
# VALID Batch Stats 0/65, Loss=0.68
# VALID Batch Stats 64/65, Loss=0.79
# VALID Epoch 3 / 5, Mean Total Loss 0.7918938398361206
# TRAIN Batch Stats 0/260, Loss=0.76
# TRAIN Batch Stats 100/260, Loss=0.89
# TRAIN Batch Stats 200/260, Loss=0.77
# TRAIN Batch Stats 259/260, Loss=0.85
# TRAIN Epoch 4 / 5, Mean Total Loss 0.788774847984314
# VALID Batch Stats 0/65, Loss=0.69
# VALID Batch Stats 64/65, Loss=0.77
# VALID Epoch 4 / 5, Mean Total Loss 0.7918063998222351
# TRAIN Batch Stats 0/260, Loss=0.84
# TRAIN Batch Stats 100/260, Loss=0.81
# TRAIN Batch Stats 200/260, Loss=0.73
# TRAIN Batch Stats 259/260, Loss=0.75
# TRAIN Epoch 4 / 5, Mean Total Loss 0.7858716249465942
# VALID Batch Stats 0/65, Loss=0.70
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 4 / 5, Mean Total Loss 0.789366602897644
# TRAIN Batch Stats 0/260, Loss=0.79
# TRAIN Batch Stats 100/260, Loss=0.84
# TRAIN Batch Stats 200/260, Loss=0.72
# TRAIN Batch Stats 259/260, Loss=0.76
# TRAIN Epoch 4 / 5, Mean Total Loss 0.7836509346961975
# VALID Batch Stats 0/65, Loss=0.70
# VALID Batch Stats 64/65, Loss=0.79
# VALID Epoch 4 / 5, Mean Total Loss 0.7879745960235596
# TRAIN Batch Stats 0/260, Loss=0.74
# TRAIN Batch Stats 100/260, Loss=0.75
# TRAIN Batch Stats 200/260, Loss=0.84
# TRAIN Batch Stats 259/260, Loss=0.83
# TRAIN Epoch 5 / 5, Mean Total Loss 0.7827808260917664
# VALID Batch Stats 0/65, Loss=0.69
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 5 / 5, Mean Total Loss 0.783433735370636
# TRAIN Batch Stats 0/260, Loss=0.74
# TRAIN Batch Stats 100/260, Loss=0.72
# TRAIN Batch Stats 200/260, Loss=0.67
# TRAIN Batch Stats 259/260, Loss=0.70
# TRAIN Epoch 5 / 5, Mean Total Loss 0.7785468697547913
# VALID Batch Stats 0/65, Loss=0.69
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 5 / 5, Mean Total Loss 0.7839460372924805
# TRAIN Batch Stats 0/260, Loss=0.69
# TRAIN Batch Stats 100/260, Loss=0.73
# TRAIN Batch Stats 200/260, Loss=0.84
# TRAIN Batch Stats 259/260, Loss=0.73
# TRAIN Epoch 5 / 5, Mean Total Loss 0.7773810029029846
# VALID Batch Stats 0/65, Loss=0.68
# VALID Batch Stats 64/65, Loss=0.78
# VALID Epoch 5 / 5, Mean Total Loss 0.778875470161438

# %%
target_tracker = []
pred_tracker = []

print("Preparing test data ...")

data_loader = DataLoader(dataset = datasets['test'], batch_size = BATCH_SIZE, shuffle=False)

print("Evaluating model on test data ...")
model.eval()
with torch.no_grad():

    for iteration, batch in enumerate(data_loader):

        for k, v in batch.items():
            batch[k] = v.to(device)

        # Forward pass
        _, pred_probs = model(batch)

        target_tracker.append(batch["fit"].cpu().numpy())
        pred_tracker.append(pred_probs.cpu().data.numpy())

target_tracker = np.stack(target_tracker[:-1]).reshape(-1)
pred_tracker = np.stack(pred_tracker[:-1], axis=0).reshape(-1, NUM_TARGETS)
precision, recall, f1_score, accuracy, auc = compute_metrics(target_tracker, pred_tracker, averaging = "weighted")

print("-" * 50)
print(f"Metrics:\n Precision = {precision}\n Recall = {recall}\n F1-score = {f1_score}\n Accuracy = {accuracy}\n AUC = {auc}\n ")
print("-" * 50)
# Out:
# Preparing test data ...
# Evaluating model on test data ...
# --------------------------------------------------
# Metrics:
#  Precision = 0.5986204503830854
#  Recall = 0.687744140625
#  F1-score = 0.5612268689187028
#  Accuracy = 0.687744140625
#  AUC = 0.6740163085876372
#
# --------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
